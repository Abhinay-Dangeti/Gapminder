# %% [markdown]
# ### Python guided project on Gapminder dataset
#
# ### Introduction
#
# Gapminder dataset explains about GDP per capita as a measure of average income per person in a country. This dataset contains information about population, life expectancy, and gdp percapita from 1952 till 2007 for each country. In this project we are going use python to address certain questions.
#
# ### Variables used in this dataset are:
#
# 1: country = Country
#
# 2: year = Data collected year
#
# 3: population = Population of each country
#
# 4: continent = Continent where country is located
#
# 5: life_exp = Life expectancy at birth
#
# 6: gdp_cap = GDP per capita
#
# ### Understanding of dataset
#
# Before moving to any dataset, we must have to understand each variable properly. For example, in this dataset nearly all columns are self-explanatory, but gdp_cap may be confusing. In this project, we have two different datasets containing information about Gapminder. Both datasets have common keys.
# GDP stands for Gross Domestic Product. This measure National income / National Output and National expenditure. GDP per capita divides the GDP by the population. Rest of the columns are self-explanatory.

# %% [markdown]
# ### Reading a Data Frame

# %%
import pandas as pd
df1=pd.read_excel(r'C:\Users\dsv24\Downloads\Gapminder_key_1.xlsx')

# %%
df1
# Out:
#           country  year  population continent
# 0     Afghanistan  1952     8425333      Asia
# 1     Afghanistan  1957     9240934      Asia
# 2     Afghanistan  1962    10267083      Asia
# 3     Afghanistan  1967    11537966      Asia
# 4     Afghanistan  1972    13079460      Asia
# ...           ...   ...         ...       ...
# 1699     Zimbabwe  1987     9216418    Africa
# 1700     Zimbabwe  1992    10704340    Africa
# 1701     Zimbabwe  1997    11404948    Africa
# 1702     Zimbabwe  2002    11926563    Africa
# 1703     Zimbabwe  2007    12311143    Africa
#
# [1704 rows x 4 columns]

# %%
df1.shape
# Out:
# (1704, 4)

# %% [markdown]
# ### Reading Another Data Frame

# %%
df2=pd.read_excel(r'C:\Users\dsv24\Downloads\Gapminder_key_2.xlsx')

# %%
df2
# Out:
#           country  year  life_exp     gdp_cap
# 0     Afghanistan  1952    28.801  779.445314
# 1     Afghanistan  1957    30.332  820.853030
# 2     Afghanistan  1962    31.997  853.100710
# 3     Afghanistan  1967    34.020  836.197138
# 4     Afghanistan  1972    36.088  739.981106
# ...           ...   ...       ...         ...
# 1699     Zimbabwe  1987    62.351  706.157306
# 1700     Zimbabwe  1992    60.377  693.420786
# 1701     Zimbabwe  1997    46.809  792.449960
# 1702     Zimbabwe  2002    39.989  672.038623
# 1703     Zimbabwe  2007    43.487  469.709298
#
# [1704 rows x 4 columns]

# %% [markdown]
# ### Merging the two data frames

# %%
Gapminder=df1.merge(df2 , on=['country','year'], how='outer')

# %%
Gapminder
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
Gapminder['life_exp'].iloc[:100]
# Out:
# 0     28.801
# 1     30.332
# 2     31.997
# 3     34.020
# 4     36.088
#        ...
# 95    75.635
# 96    37.484
# 97    39.348
# 98    41.216
# 99    43.453
# Name: life_exp, Length: 100, dtype: float64

# %% [markdown]
# ### Exploring the basic information

# %%
len(Gapminder)
# Out:
# 1704

# %%
Gapminder.shape
# Out:
# (1704, 6)

# %%
Gapminder.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
Gapminder=Gapminder.astype({'country':'category','continent':'category'})

# %%
Gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   category
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   category
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: category(2), float64(2), int64(2)
# memory usage: 76.9 KB

# %%
Gapminder['country'].nunique()
# Out:
# 142

# %%
Gapminder['country'].value_counts(ascending=True)
# Out:
# Afghanistan    12
# Portugal       12
# Poland         12
# Philippines    12
# Peru           12
#                ..
# Ghana          12
# Greece         12
# Guatemala      12
# France         12
# Zimbabwe       12
# Name: country, Length: 142, dtype: int64

# %% [markdown]
# ### Finding the min life_exp in the Gapminder data frame

# %%
Gapminder[Gapminder.life_exp == Gapminder.life_exp.min()]
# Out:
#      country  year  population continent  life_exp     gdp_cap
# 1292  Rwanda  1992     7290203    Africa    23.599  737.068595

# %%
Gapminder_2007=Gapminder[Gapminder['year']==2007]  # created a new table which contains columns that are present in 2007.
Gapminder_2007[Gapminder_2007.life_exp == Gapminder_2007.life_exp.min()]
# with the help of boolean indexing we are filtering the table.
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 1463  Swaziland  2007     1133066    Africa    39.613  4513.480643

# %%
Gapminder_2007
# Out:
#                  country  year  population continent  life_exp       gdp_cap
# 11           Afghanistan  2007    31889923      Asia    43.828    974.580338
# 23               Albania  2007     3600523    Europe    76.423   5937.029526
# 35               Algeria  2007    33333216    Africa    72.301   6223.367465
# 47                Angola  2007    12420476    Africa    42.731   4797.231267
# 59             Argentina  2007    40301927  Americas    75.320  12779.379640
# ...                  ...   ...         ...       ...       ...           ...
# 1655             Vietnam  2007    85262356      Asia    74.249   2441.576404
# 1667  West Bank and Gaza  2007     4018332      Asia    73.422   3025.349798
# 1679         Yemen, Rep.  2007    22211743      Asia    62.698   2280.769906
# 1691              Zambia  2007    11746035    Africa    42.384   1271.211593
# 1703            Zimbabwe  2007    12311143    Africa    43.487    469.709298
#
# [142 rows x 6 columns]

# %% [markdown]
# ### The country that has highest GDP in 2007

# %%
# which country has the higest gdp in 2007
Gapminder_2007['gdp']= Gapminder_2007['gdp_cap'] * Gapminder_2007['population']
Gapminder_2007[Gapminder_2007.gdp== Gapminder_2007.gdp.max()] 
# with the help of boolean indexing we are filtering the table
# Out:
# C:\Users\dsv24\AppData\Local\Temp/ipykernel_10456/799001465.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Gapminder_2007['gdp']= Gapminder_2007['gdp_cap'] * Gapminder_2007['population']
#             country  year  population continent  life_exp      gdp_cap  \
# 1619  United States  2007   301139947  Americas    78.242  42951.65309
#
#                gdp
# 1619  1.293446e+13

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import random

# %%
x=list(Gapminder['life_exp'].iloc[:100])
y=list(Gapminder['year'].iloc[:100])

# %% [markdown]
# ### Is there any change in the trend from 1952 to 2007 in life expectancy

# %%
plt.figure(figsize=(5,5))
plt.title("trend from 1952 to 2007 in life expectancy")
plt.scatter(x,y,color='r')# r- red,k-black,c-cyan,w-white,m-magenta
plt.ylabel('year')
plt.xlabel('life_exp')
plt.show()

# %% [markdown]
# ### Which continent has the lowest life expectancy in 2007?

# %%
Gapminder_2007[Gapminder_2007.life_exp==Gapminder_2007.life_exp.min()]
# Out:
#         country  year  population continent  life_exp      gdp_cap  \
# 1463  Swaziland  2007     1133066    Africa    39.613  4513.480643
#
#                gdp
# 1463  5.114071e+09

# %%
for i in Gapminder_2007:
  if [Gapminder_2007.life_exp==Gapminder_2007.life_exp.min()]:
    print(Gapminder_2007['continent'])
    break
  else:
    pass
# Out:
# 11          Asia
# 23        Europe
# 35        Africa
# 47        Africa
# 59      Americas
#           ...
# 1655        Asia
# 1667        Asia
# 1679        Asia
# 1691      Africa
# 1703      Africa
# Name: continent, Length: 142, dtype: category
# Categories (5, object): ['Africa', 'Americas', 'Asia', 'Europe', 'Oceania']

# %%
Gapminder_2007.life_exp==Gapminder_2007.life_exp.min()
# Out:
# 11      False
# 23      False
# 35      False
# 47      False
# 59      False
#         ...
# 1655    False
# 1667    False
# 1679    False
# 1691    False
# 1703    False
# Name: life_exp, Length: 142, dtype: bool

# %% [markdown]
# ### The average life expectancy, GDP and gdp per capita in 2007

# %%
Gapminder_2007.groupby('country')['gdp_cap','gdp','life_exp'].mean()
# Out:
# C:\Users\dsv24\AppData\Local\Temp/ipykernel_10456/3522210315.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Gapminder_2007.groupby('country')['gdp_cap','gdp','life_exp'].mean()
#                          gdp_cap           gdp  life_exp
# country
# Afghanistan           974.580338  3.107929e+10    43.828
# Albania              5937.029526  2.137641e+10    76.423
# Algeria              6223.367465  2.074449e+11    72.301
# Angola               4797.231267  5.958390e+10    42.731
# Argentina           12779.379640  5.150336e+11    75.320
# ...                          ...           ...       ...
# Vietnam              2441.576404  2.081746e+11    74.249
# West Bank and Gaza   3025.349798  1.215686e+10    73.422
# Yemen, Rep.          2280.769906  5.065987e+10    62.698
# Zambia               1271.211593  1.493170e+10    42.384
# Zimbabwe              469.709298  5.782658e+09    43.487
#
# ...

# %%
Gapminder_2007[Gapminder_2007.gdp_cap== Gapminder_2007.gdp_cap.min()]
# Out:
#               country  year  population continent  life_exp     gdp_cap  \
# 335  Congo, Dem. Rep.  2007    64606759    Africa    46.462  277.551859
#
#               gdp
# 335  1.793173e+10

# %% [markdown]
# ### Is there any relationship between life expectancy and gdp per capita? Please show each data point by continent.

# %%
# Gapminder.groupby(['continent','gdp_cap'])['life_exp'].sum()
plt.figure(figsize=(12,12))
sns.displot(x='life_exp',y='gdp_cap',data=Gapminder)

# %%
sns.regplot(x='life_exp',y='gdp_cap',data=Gapminder)
# Out:
# <AxesSubplot:xlabel='life_exp', ylabel='gdp_cap'>

# %%
sns.pairplot(Gapminder,hue='continent',vars=['life_exp','gdp_cap'],)

# %%
sns.pairplot(Gapminder,hue='continent',)

# %%
sns.heatmap(Gapminder.corr()*100,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What can be done to see the relationship better between life expectancy and gdp percapita?

# %%
Gapminder_india=Gapminder[Gapminder['country']=='India']
Gapminder_india
k=list(Gapminder_india['gdp_cap'])
l=list(Gapminder_india['life_exp'])

plt.title('the relationship better between life expectancy and gdp percapita')
plt.plot(k,l,'go--',marker='o',color='red',markersize=12)
plt.xlabel('Gdp per capita')
plt.ylabel('LIFE EXPECTANCY')
# Out:
# C:\Users\dsv24\AppData\Local\Temp/ipykernel_10456/2581020924.py:7: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "go--" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(k,l,'go--',marker='o',color='red',markersize=12)
# C:\Users\dsv24\AppData\Local\Temp/ipykernel_10456/2581020924.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(k,l,'go--',marker='o',color='red',markersize=12)
# Text(0, 0.5, 'LIFE EXPECTANCY')

# %%
k=list(Gapminder_india['gdp_cap'])
l=list(Gapminder_india['life_exp'])
Gapminder_india=Gapminder[Gapminder['country']=='India']
Gapminder_india
plt.title('the relationship better between life expectancy and gdp percapita')
plt.scatter(k,l)
plt.xlabel('Gdp per capita')
plt.ylabel('LIFE EXPECTANCY')
# Out:
# Text(0, 0.5, 'LIFE EXPECTANCY')

# %%
sns.regplot(k,l,marker='o')
# Out:
# C:\Users\dsv24\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %% [markdown]
# ### What is the trend of life expectancy in India from 1952 - 2007?

# %%
p=list(Gapminder_india['year'])
q=list(Gapminder_india['life_exp'])
Gapminder_india=Gapminder[Gapminder['country']=='India']
Gapminder_india
plt.title('The trend of life expectancy in India form 1952-2007')
plt.plot(p,q,'go--',marker='o',color='red',markersize=12)
plt.xlabel('YEAR')
plt.ylabel('LIFE EXPECTANCY')
# Out:
# C:\Users\dsv24\AppData\Local\Temp/ipykernel_10456/1593798207.py:7: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "go--" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(p,q,'go--',marker='o',color='red',markersize=12)
# C:\Users\dsv24\AppData\Local\Temp/ipykernel_10456/1593798207.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(p,q,'go--',marker='o',color='red',markersize=12)
# Text(0, 0.5, 'LIFE EXPECTANCY')

# %%
x=list(Gapminder_india['year'])
y=list(Gapminder_india['gdp_cap'])

# %% [markdown]
# ### What is the trend of GDP per capita in India from 1952 - 2007?

# %%
Gapminder_india=Gapminder[Gapminder['country']=='India']
Gapminder_india
plt.title('The trend of GDP per capita in India form 1952-2007')
plt.plot(x,y,'go--',marker='o',color='green',markersize=12)
plt.xlabel('YEAR')
plt.ylabel('GDP per capita')
# Out:
# C:\Users\dsv24\AppData\Local\Temp/ipykernel_10456/3226721478.py:4: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "go--" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(x,y,'go--',marker='o',color='green',markersize=12)
# C:\Users\dsv24\AppData\Local\Temp/ipykernel_10456/3226721478.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go--" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(x,y,'go--',marker='o',color='green',markersize=12)
# Text(0, 0.5, 'GDP per capita')

# %% [markdown]
# ### What is the median age of each continent by year?

# %%
Gapminder.groupby(['year','continent'])['life_exp'].median()
# Out:
# year  continent
# 1952  Africa       38.8330
#       Americas     54.7450
#       Asia         44.8690
#       Europe       65.9000
#       Oceania      69.2550
# 1957  Africa       40.5925
#       Americas     56.0740
#       Asia         48.2840
#       Europe       67.6500
#       Oceania      70.2950
# 1962  Africa       42.6305
#       Americas     58.2990
#       Asia         49.3250
#       Europe       69.5250
#       Oceania      71.0850
# 1967  Africa       44.6985
#       Americas     60.5230
#       Asia         53.6550
#       Europe       70.6100
#       Oceania      71.3100
# 1972  Africa       47.0315
#       Americas     63.4410
#       Asia         56.9500
#       Europe       70.8850
#       Oceania      71.9100
# 1977  Africa       49.2725
#       Americas     66.3530
#       Asia         60.7650
#       Europe       72.3350
#       Oceania      72.8550
# 1982  Africa       50.7560
#       Americas     67.4050
#       Asia         63.7390
# ...
